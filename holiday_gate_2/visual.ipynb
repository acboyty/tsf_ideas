# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
y_test = np.load('/home/v-tyan/tsf_ideas/holiday_gate/sin/y_test.npy')
forecast = np.load('/home/v-tyan/tsf_ideas/holiday_gate/sin/forecast.npy')

# %%
y_test.shape
# Out:
# (205, 7)

# %%
timestamp = 110

plt.figure(figsize=(10,5))
plt.plot(y_test[timestamp])
plt.plot(forecast[timestamp])
plt.legend(['y_test', 'forecast'])
plt.grid(True)

# %%
plt.figure(figsize=(20, 6))
plt.plot(np.concatenate((y_test[:, 0], y_test[-1, 1:])))
plt.grid(True)
